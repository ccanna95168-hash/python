# %% [markdown]
# <a href="https://colab.research.google.com/github/ccanna95168-hash/python/blob/main/05_%EB%A6%AC%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 05. 리스트

# %% [markdown]
# ## 1. 리스트의 개요
# * **개념**: 리스트(list)는 여러 개의 데이터를 하나의 이름으로 묶어서 저장하는 자료형입니다.
# * **필요성**: 역할이 비슷한 변수가 많아질 때 리스트를 사용하면 프로그램이 간결해지고 데이터 관리가 쉬워집니다.
# * **리스트 생성**: 대괄호 `[]`를 사용하며, 항목은 쉼표(`,`)로 구분합니다.
#     * 예: `prices = [1000, 2000, 3000]`
# * **항목 접근 (Indexing)**: 리스트의 각 항목은 인덱스 번호를 가지며, **0번부터 시작**합니다.
#     * 예: `prices[0]`은 첫 번째 항목인 1000을 의미합니다.

# %%
prices = [1500,3200,2500,4000,5500]
for i in range(len(prices)): #len(prices): 0,1,2,3,4 5개의 인덱스
  prices[i] = prices[i] + prices[i]*0.05
print(prices)

# %%
menus=['짜장면','짬뽕','볶음밥']
for i in range(len(menus)): #len(menus): 3개의 인덱스
  print(menus[i])

# %%
# 빈 리스트 생성 후 값 추가하기
menus = []
menus.append('짜장면')
menus.append('짬뽕')
menus.append('볶음밥')
print(menus)

# %%
# 1~10까지 정수를 세제곱한 수를 리스트 저장
cubes = []
for i in range(1,11):
  cubes.append(i**3)
print(cubes)

# %% [markdown]
# ### 리스트 내포 (list comprehension):
# [] 안에 `for문`과  `조건식`을 내포시켜 한줄로 생성
#
#
# *   [조건식 for 변수 in 반복가능한것 if 조건문]

# %%
cubes =[i**3 for i in range(1,11)]
print(cubes)

# %%
#1~100 중에서 7의 배수를 리스트에 저장
sequence = []
for i in range(1,101):
  if i % 7 == 0:
    sequence.append(i)
print(sequence)

# %%
sequence = [ i for i in range(1,101) if i % 7 == 0]
print(sequence)

# %%
score =[71,80,60,90,65]
result = []

for i in score:
  if i >= 70:
    result.append("합격")
  else:
    result.append("불합격")
print(result)

# %%
#리스트 내포
score =[71,80,60,90,65]
result = ["합격" if i >= 70 else "불합격" for i in score]
print(result)

# %% [markdown]
# ## 2. 리스트 생성과 인덱싱
#
# * **생성**: 대괄호(`[]`)를 사용하며, 각 요소는 쉼표(`,`)로 구분합니다.
#     * 예: `fruits = ['apple', 'banana', 'cherry']`
# * **인덱싱**: 리스트의 각 요소에 접근하기 위한 번호표로, **0번**부터 시작합니다.
#     * `fruits[0]`은 'apple', `fruits[1]`은 'banana'를 가리킵니다.

# %%
menus=['짜장면','짬뽕','볶음밥']
print(menus[1])
menus[2] = '탕수육' #인덱스 바꾸기
print(menus)

print(menus[-1]) # 인덱스 번호가 역으로 바뀜
print(menus[-2])
print(menus[-3])

for i in range(len(menus)): # 0 1 2
  print(menus[i])

# %% [markdown]
# * len(리스트) : 리스트의 길이, 항목의 전체 개수를 반환
# * enumerate() : 인덱스와 항목을 모두 반환

# %%
fruits = ["apple", "banana", "cherry"]

for index, item in enumerate(fruits):
    print(index, item)

# %% [markdown]
# * 슬라이싱(slicing) : 리스트의 일부 항복 추출
# * 리스트[시작 인덱스:종료인덱스]

# %%
#슬라이싱
letters=['A','B','C','D','E',]
print(letters[1:3])
print(letters[:4])
print(letters[2:])
print(letters[1:-1])
# Out:
# ['B', 'C']
# ['A', 'B', 'C', 'D']
# ['C', 'D', 'E']

# %% [markdown]
# ## 3. 리스트 주요 메서드
#
# 리스트의 요소를 추가, 수정, 삭제하는 다양한 기능을 제공합니다.
#
# * **추가**: `.append(값)` (끝에 추가), `.insert(위치, 값)` (특정 위치에 삽입), `.extend(리스트)` (다른 리스트와 합침)
# * **삭제**: `.remove(값)` (첫 번째 일치하는 값 삭제), `.pop(위치)` (특정 위치의 값을 꺼내고 리스트에서 제거)

# %%
pl = []
pl.append('파이썬')
pl.append('자바스크립트')
print(pl)

# %%
pl = ['파이썬','자바스크립트']
pl.insert(1,'c언어')
print(pl)

# %%
pl = ['파이썬','자바스크립트']
pl.extend(['c언어','c++'])
print(pl)

# %%
pets = ['강아지','고양이','햄스터','너구리']
select1 = pets.pop(3) #인덱스 3번 추출되고 나머지는 그대로 저장
print(select1)
print(pets)

select2 = pets.pop() # 값 지정 안하면 맨 마지막 인덱스 삭제
print(select2)
print(pets)

del pets[0] # del키워드는 삭제한 항목은 반환되지 않음 (강아지 삭제)
print(pets)

# %%
pets = ['강아지','고양이','햄스터','너구리','강아지']
pets.remove('강아지') #첫번째로 일치하는: 강아지 삭제
print(pets)

pets.clear() #리스트 전체 삭제
print(pets)

# %% [markdown]
# ## 4. 리스트 탐색 및 정렬
#
# * **탐색**: `len(리스트)` (길이 확인), `.count(값)` (특정 값의 개수 확인)
# * **정렬**: `.sort()` (원본 리스트를 오름차순 정렬), `sorted(리스트)` (정렬된 새로운 리스트 반환)

# %%
# sort() 원본을 직접 정렬
numbers = [3,1,4,2]
numbers.sort()
print(numbers)

# sorted() 원본은 유지, 정렬된 새로운 리스트를 반환
numbers_sorted = [5,8,6,9]
new_numbers=sorted(numbers_sorted)
print(numbers_sorted)
print(new_numbers)
# Out:
# [1, 2, 3, 4]
# [5, 8, 6, 9]
# [5, 6, 8, 9]

# %%
#.reverse() 리스트를 역순으로 원본 변경
nations = ['한국','일본','중국','미국']
nations.reverse()
print(nations)
# Out:
# ['미국', '중국', '일본', '한국']

# %%
# 값 in 리스트 : 리스트에 값이 있으면 True, 없으면 False
months = ['January','February','March','April','May','June','July','August','September','October','November','December']
answer = input('월(영어):')

if answer in months:
  print(f'{months.index(answer)+1}월')
else:
  print('잘못 입력했습니다.')
# Out:
# 월(영어):May
# 5월

# %%
import random
colors = ['red','green','blue','yellow','purple']

#random.choice(리스트) - 리스트에서 무작위로 선택
print(random.choice(colors))

#random.sample(리스트,개수) : 리스트 항목에서 개수 만큼 중복 없이 무작위로 선택
print(random.sample(colors,3))

#random.choices(리스트.k=개수) : 중복 허용
print(random.choices(colors,k=3))

#random.shuffle(리스트)
random.shuffle(colors)
print(colors)
# Out:
# purple
# ['yellow', 'green', 'red']
# ['purple', 'blue', 'yellow']
# ['yellow', 'green', 'blue', 'red', 'purple']

# %%
# 로또 번호 생성
# 1~45 숫자 생성하고 배열에 저장
# 중복없이 무작위로 6개 숫자만 선택
# 새로운 배열에 추가

import random

number = []
for i in range(1,46):
  number.append(i)

random.shuffle(number)
print(number)

resulit_number = random.sample(number,6)
print(resulit_number)
# Out:
# [9, 15, 12, 32, 36, 33, 2, 27, 41, 8, 37, 45, 29, 18, 11, 21, 1, 30, 17, 4, 7, 43, 39, 25, 31, 24, 22, 3, 28, 16, 35, 44, 5, 26, 23, 42, 34, 40, 20, 19, 13, 6, 10, 14, 38]
# [44, 17, 38, 14, 18, 31]

# %%
# .count(값) : 리스트에서 특정 값이 몇개 있는지 개수 반환
fruits =['apple','banana','apple','cherry','apple']
apple_count= fruits.count('apple')
print(f'사과 개수: {apple_count}')
# Out:
# 사과 개수: 3

# %%
# 문제: 3개의 이름을 입력 받아서 names 리스트에 저장하고 정렬하고 출력

names=[]
for i in range(3):
  name = input('이름:')
  names.append(name)
names.sort()
print(names)
# Out:
# 이름:김
# 이름:박
# 이름:이
# ['김', '박', '이']

# %%
# 문제: 거꾸로 항목 하나씩 출력하기
pl = ['파이썬','자바스크립트','c언어','c++']
for i in range(len(pl)-1,-1,-1):
  print(pl[i])
# Out:
# c++
# c언어
# 자바스크립트
# 파이썬

# %%
# 학생 수 만큼 입력받은 학생 명단에서 무작위로 두명만 선택
names=[]
num = int(input('학생 수: '))
for i in range(num):
  name = input('학생 이름: ')
  names.append(name)

names = random.sample(names, 2)
print(names)
# Out:
# 학생 수: 4
# 학생 이름: ㅂ
# 학생 이름: ㅈ
# 학생 이름: ㄷ
# 학생 이름: ㄱ
# ['ㄷ', 'ㅈ']

# %% [markdown]
# ## 5. [실습 예제]
#
# ## 삼각비 값 찾기 사전
# 리스트의 인덱싱 기능을 활용하여 특정 각도에 대한 삼각비 값을 출력하는 프로그램을 만들어 봅니다.
# ### 코드 로직
# 1. **데이터 저장**: 15개의 삼각비 명칭과 그에 대응하는 값을 리스트에 각각 저장합니다.
# 2. **사용자 입력**: 사용자로부터 0~14 사이의 인덱스 번호를 입력받습니다.
# 3. **결과 출력**: 입력받은 번호를 리스트의 인덱스로 사용하여 해당 각도와 값을 매칭해 보여줍니다.

# %%
# 삼각비 검색기
angles = ['sin0','sin30','sin45','sin60','sin90',
          'cos0','cos30','cos45','cos60','cos90',
          'tan0','tan30','tan45','tan60','tan90']
values = ['0','1/2','√2/2','√3/2','1',
          '1','√3/2','√2/2','1/2','0',
          '0','√3/3','1','√3','정의 되지 않음']

# zip 함수를 사용하여 이름과 같은 값을 짝지어 출력
for name, val in zip(angles, values):
  print(f'{name} = {val}')
# Out:
# sin0 = 0
# sin30 = 1/2
# sin45 = √2/2
# sin60 = √3/2
# sin90 = 1
# cos0 = 1
# cos30 = √3/2
# cos45 = √2/2
# cos60 = 1/2
# cos90 = 0
# tan0 = 0
# tan30 = √3/3
# tan45 = 1
# tan60 = √3
# tan90 = 정의 되지 않음

# %%
while True :
  tri = input('알고 싶은 삼각비의 각도를 입력해주세요. 또는 종료.')

  if tri == '종료':
    print('프로그램을 종료합니다.')
    break
  elif tri in angles:
    index = angles.index(tri)
    print(f'{tri}의 감각비는 {values[index]} 입니다.')
  else:
    print('찾을 수 없는 삼각비입니다. 다시 입력해주세요.')
# Out:
# 알고 싶은 삼각비의 각도를 입력해주세요. 또는 종료.sin30
# sin30의 감각비는 1/2 입니다.
# 알고 싶은 삼각비의 각도를 입력해주세요. 또는 종료.g
# 찾을 수 없는 삼각비입니다. 다시 입력해주세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2222330861.py in <cell line: 0>()
#       1 while True :
# ----> 2   tri = input('알고 싶은 삼각비의 각도를 입력해주세요. 또는 종료.')
#       3
#       4   if tri == '종료':
#       5     print('프로그램을 종료합니다.')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## 원소 검색기
# 1. **이중 리스트 구조**: 원소 기호 리스트(`element_symbol`)와 원소 이름 리스트(`element_name`)를 별도로 만듭니다.
# 2. **반복문 결합**: `for` 문과 `range(len(리스트))`를 사용하여 전체 원소 기호와 이름을 짝지어 출력합니다.
# 3. **검색 로직**:
#     * 사용자가 원소 기호(예: 'H')를 입력합니다.
#     * 기호 리스트에서 해당 기호의 위치(`index`)를 찾습니다.
#     * 찾은 인덱스를 이름 리스트에 적용하여 '수소'를 출력합니다.

# %%
element_symbol = ['H','He','Li','Be','B','C','N','O','F','Ne',
'Na','Mg','Al','Si','P','S','Cl','Ar','K','Ca',
'Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu','Zn',
'Ga','Ge','As','Se','Br','Kr','Rb','Sr','Y','Zr',
'Nb','Mo','Tc','Ru','Rh','Pd','Ag','Cd','In','Sn',
'Sb','Te','I','Xe','Cs','Ba','La','Ce','Pr','Nd',
'Pm','Sm','Eu','Gd','Tb','Dy','Ho','Er','Tm','Yb',
'Lu','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg',
'Ti','Pb','Bi','Po','At','Rn','Fr','Ra','Ac','Th',
'Pa','U','Np','Pu','Am','Cm','Bk','Cf','Es','Fm',
'Md','No','Lr','Rf','Db','Sg','Bh','Hs','Mt','Ds',
'Rg','Cn','Nh','Fl','Mc','Lv','Ts','Og']
element_name = ['수소','헬륨','리튬','베릴륨','붕소','탄소','질소','산소','플루오린','네온',
'나트륨','마그네슘','알루미늄','규소','인','황','염소','아르곤','칼륨','칼슘',
'스칸듐','타이타늄','바나듐','크로뮴','망가니즈','철','코발트','니켈','구리','아연',
'갈륨','저마늄','비소','셀레늄','브로민','크립톤','루비듐','스트론튬','이트륨','지르코늄',
'나이오븀','몰리브데넘','테크네튬','루테늄','로듐','팔라듐','은','카드뮴','인듐','주석',
'안티모니','텔루륨','아이오딘','제논','세슘','바륨','란타넘','세륨','프라세오디뮴','네오디뮴',
'프로메튬','사마륨','유로퓸','가돌리늄','터븀','디스프로슘','홀뮴','어븀','툴륨','이터븀',
'루테튬','하프늄','탄탈럼','텅스텐','레늄','오스뮴','이리듐','백금','금','수은',
'탈륨','납','비스무트','폴로늄','아스타틴','라돈','프랑슘','라듐','악티늄','토륨',
'프로탁티늄','우라늄','넵투늄','플루토늄','아메리슘','퀴륨','버클륨','칼리포늄','아인슈타이늄','페르뮴',
'멘델레븀','노벨륨','로렌슘','러더포듐','더브늄','시보귬','보륨','하슘','마이트너륨','다름슈타듐',
'뢴트게늄','코페르니슘','니호늄','플레로븀','모스코븀','리버모륨','테네신','오가네손']

print(len(element_symbol))

for i in range(len(element_symbol)):
  print(element_symbol[i], element_name[i])
# Out:
# 118
# H 수소
# He 헬륨
# Li 리튬
# Be 베릴륨
# B 붕소
# C 탄소
# N 질소
# O 산소
# F 플루오린
# Ne 네온
# Na 나트륨
# Mg 마그네슘
# Al 알루미늄
# Si 규소
# P 인
# S 황
# Cl 염소
# Ar 아르곤
# K 칼륨
# Ca 칼슘
# Sc 스칸듐
# Ti 타이타늄
# V 바나듐
# Cr 크로뮴
# Mn 망가니즈
# Fe 철
# Co 코발트
# Ni 니켈
# Cu 구리
# Zn 아연
# Ga 갈륨
# Ge 저마늄
# As 비소
# Se 셀레늄
# Br 브로민
# Kr 크립톤
# Rb 루비듐
# Sr 스트론튬
# Y 이트륨
# Zr 지르코늄
# Nb 나이오븀
# Mo 몰리브데넘
# Tc 테크네튬
# Ru 루테늄
# Rh 로듐
# Pd 팔라듐
# Ag 은
# Cd 카드뮴
# In 인듐
# Sn 주석
# Sb 안티모니
# Te 텔루륨
# I 아이오딘
# Xe 제논
# Cs 세슘
# Ba 바륨
# La 란타넘
# Ce 세륨
# Pr 프라세오디뮴
# Nd 네오디뮴
# Pm 프로메튬
# Sm 사마륨
# Eu 유로퓸
# Gd 가돌리늄
# Tb 터븀
# Dy 디스프로슘
# Ho 홀뮴
# Er 어븀
# Tm 툴륨
# Yb 이터븀
# Lu 루테튬
# Hf 하프늄
# Ta 탄탈럼
# W 텅스텐
# Re 레늄
# Os 오스뮴
# Ir 이리듐
# Pt 백금
# Au 금
# Hg 수은
# Ti 탈륨
# Pb 납
# Bi 비스무트
# Po 폴로늄
# At 아스타틴
# Rn 라돈
# Fr 프랑슘
# Ra 라듐
# Ac 악티늄
# Th 토륨
# Pa 프로탁티늄
# U 우라늄
# Np 넵투늄
# Pu 플루토늄
# Am 아메리슘
# Cm 퀴륨
# Bk 버클륨
# Cf 칼리포늄
# Es 아인슈타이늄
# Fm 페르뮴
# Md 멘델레븀
# No 노벨륨
# Lr 로렌슘
# Rf 러더포듐
# Db 더브늄
# Sg 시보귬
# Bh 보륨
# Hs 하슘
# Mt 마이트너륨
# Ds 다름슈타듐
# Rg 뢴트게늄
# Cn 코페르니슘
# Nh 니호늄
# Fl 플레로븀
# Mc 모스코븀
# Lv 리버모륨
# Ts 테네신
# Og 오가네손

# %%
# 원소 검색기
# '원소 기호, 원소 이름, 종료' 입력 받고
# while문 사용 해서 반복, 종료 나오면 break
# 원소 기호라고 입력한 경우 -> 해당 원소 기호를 리스트에서 찾아서 원자 번호와 원소 이름을 출력
# 원소 이름이라고 입력한 경우 -> 해당 원소 이름을 리스트에서 찾아서 원자 번호롸 원소 기호를 출력

while True:
  element = input('원소를 입력해주세요.(기호 or 이름 or 종료)')
  if element == '종료':
    print('종료 하겠습니다.')
    break
  elif element in element_symbol:
    index = element_symbol.index(element)
    print(f'입력하신 {element}의 원자 번호는 {index + 1} 이고, 원소 이름은 {element_name[index]} 입니다.')
  elif element in element_name:
    index = element_name.index(element)
    print(f'입력하신 {element}의 원자 번호는 {index + 1} 이고, 원소 기호는 {element_symbol[index]} 입니다.')
  else:
    print('찾을 수 없는 원소입니다. 다시 입력해주세요.')
# Out:
# 원소를 입력해주세요.(기호 or 이름 or 종료)종료
# 종료 하겠습니다.
